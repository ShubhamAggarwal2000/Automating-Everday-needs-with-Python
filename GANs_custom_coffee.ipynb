# %%
# %pip install gdown
# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# 1.15.2
# Mounted at /content/drive

# %%
# Use this file for training on custom dataset
# for example coffee dataset

# %%
# !git clone https://github.com/NVlabs/stylegan2.git
# %cd stylegan2
# Out:
# Cloning into 'stylegan2'...
# remote: Enumerating objects: 93, done.
# remote: Total 93 (delta 0), reused 0 (delta 0), pack-reused 93
# Unpacking objects: 100% (93/93), done.
# /content/stylegan2

# %%
# %mkdir raw_dataset
# %cd raw_dataset

# %%
# !gdown --id 1FD2gC68bkKaZKuh_PhvrmMRDemLLIMo9
# this is the id for the dataset in single folder uploaded change according to project
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1FD2gC68bkKaZKuh_PhvrmMRDemLLIMo9
# To: /content/stylegan2/raw_dataset/single_folder.zip
# 12.1MB [00:00, 16.9MB/s]

# %%
# !unzip single_folder.zip
# Out:
# Archive:  single_folder.zip
#    creating: single_folder/
#   inflating: single_folder/0.jpg
#   inflating: single_folder/1.jpg
#   inflating: single_folder/10.jpg
#   inflating: single_folder/100.jpg
#   inflating: single_folder/101.jpg
#   inflating: single_folder/102.jpg
#   inflating: single_folder/103.jpg
#   inflating: single_folder/104.jpg
#   inflating: single_folder/105.jpg
#   inflating: single_folder/106.jpg
#   inflating: single_folder/107.jpg
#   inflating: single_folder/108.jpg
#   inflating: single_folder/109.jpg
#   inflating: single_folder/11.jpg
#   inflating: single_folder/110.jpg
#   inflating: single_folder/111.jpg
#   inflating: single_folder/112.jpg
#   inflating: single_folder/113.jpg
#   inflating: single_folder/114.jpg
#   inflating: single_folder/115.jpg
#   inflating: single_folder/116.jpg
#   inflating: single_folder/117.jpg
#   inflating: single_folder/118.jpg
#   inflating: single_folder/119.jpg
#   inflating: single_folder/12.jpg
# ...

# %%
# !python dataset_tool.py create_from_images ./datasets/coffee_dataset ./raw_dataset/single_folder
# !ls
# Out:
# Loading images from "./raw_dataset/single_folder"
# Creating dataset "./datasets/coffee_dataset"
# Added 500 images.
# datasets	 LICENSE.txt		 README.md	   test_nvcc.cu
# dataset_tool.py  metrics		 run_generator.py  training
# dnnlib		 pretrained_networks.py  run_metrics.py
# Dockerfile	 projector.py		 run_projector.py
# docs		 raw_dataset		 run_training.py

# %%
# !python run_training.py --num-gpus=1 --data-dir=./datasets --config=config-e \
  --dataset=coffee_dataset --mirror-augment=true
# Out:
# Local submit - run_dir: results/00000-stylegan2-coffee_dataset-1gpu-config-e
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# tcmalloc: large alloc 4294967296 bytes == 0x7bd6000 @  0x7fe3b99d4001 0x7fe3b6460765 0x7fe3b64c4bb0 0x7fe3b64c6a4f 0x7fe3b655d048 0x50a7f5 0x50cfd6 0x507f24 0x509202 0x594b01 0x54a17f 0x5517c1 0x59fe1e 0x50d596 0x507f24 0x588fac 0x59fe1e 0x50d596 0x507f24 0x588fac 0x59fe1e 0x50d596 0x509918 0x50a64d 0x50c1f4 0x509918 0x50a64d 0x50c1f4 0x507f24 0x588fac 0x59fe1e
# tcmalloc: large alloc 4294967296 bytes == 0x7fe1faac8000 @  0x7fe3b99d21e7 0x7fe3b64605e1 0x7fe3b64c4c78 0x7fe3b64c4f37 0x7fe3b655cf28 0x50a7f5 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x509918 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50c1f4 0x507f24 0x509c50 0x50a64d 0x50cfd6 0x507f24
# ...
